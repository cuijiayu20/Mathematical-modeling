# %%
import xlrd
import numpy as np
import xlwt
file1="a.xls"
data=xlrd.open_workbook(file1)
sheet=data.sheet_by_index(1)


ghl=np.zeros([sheet.nrows,sheet.ncols])
sghl=np.zeros([403,1])



for row in range(1,sheet.nrows):
    for col in range(2,sheet.ncols):
        ghl[row,col]=sheet.cell_value(row,col)
np.shape(ghl)
for row in range(403):
    sum=0
    for col in range(242):
        sum=sum+ghl[row,col]
    sghl[row,0]=sum



file2=xlwt.Workbook()
sheet1= file2.add_sheet("sheet1",cell_overwrite_ok=True)
for i in range(1,403):
        sheet1.write(i,2,sghl[i-1,0])
        print(sghl[i-1,0])
for i in range(sheet.ncols):
        sheet1.write(0,i,sheet.cell_value(0,i))
for j in range(sheet.nrows):
    sheet1.write(j,0,sheet.cell_value(j,0))
for j in range(sheet.nrows):
    sheet1.write(j,1,sheet.cell_value(j,1))

file2.save("sa.xls")
# Out:
# 0.0
# 49.0
# 273.0
# 13138.0
# 64.0
# 6912.0
# 30.0
# 6948.0
# 41.0
# 31.0
# 170.0
# 85.0
# 29.0
# 44.0
# 28.0
# 28.0
# 37.0
# 138.0
# 66.0
# 109.0
# 72.0
# 80.0
# 140.0
# 1631.0
# 124.0
# 375.0
# 28.0
# 81.0
# 106.0
# 68.0
# 162.0
# 41207.0
# 71.0
# 30.0
# 30.0
# 144.0
# 124.0
# 50686.0
# 36.0
# 385.0
# 31905.0
# 71.0
# 138.0
# 39.0
# 30.0
# 31.0
# 197.0
# 66.0
# 65.0
# 38.0
# 66.0
# 29.0
# 54.0
# 77.0
# 413.0
# 24041.0
# 28.0
# 50.0
# 34.0
# 47.0
# 86.0
# 84.0
# 75.0
# 30.0
# 397.0
# 189.0
# 388.0
# 233.0
# 42.0
# 169.0
# 46.0
# 191.0
# 28.0
# 32.0
# 13051.0
# 390.0
# 376.0
# 128.0
# 8553.0
# 64.0
# 19237.0
# 49.0
# 58.0
# 28.0
# 70.0
# 46.0
# 17949.0
# 64.0
# 425.0
# 141.0
# 145.0
# 73.0
# 398.0
# 36.0
# 41.0
# 32.0
# 73.0
# 63.0
# 413.0
# 60.0
# 42.0
# 56.0
# 131.0
# 30.0
# 155.0
# 120.0
# 77.0
# 69.0
# 240950.0
# 36.0
# 426.0
# 31.0
# 123.0
# 385.0
# 10931.0
# 398.0
# 75.0
# 123.0
# 66.0
# 29.0
# 33.0
# 137.0
# 73.0
# 6449.0
# 34.0
# 49.0
# 47540.0
# 158.0
# 133.0
# 1525.0
# 60.0
# 137512.0
# 63.0
# 71.0
# 52.0
# 87.0
# 42.0
# 33.0
# 411.0
# 151862.0
# 302047.0
# 420.0
# 121.0
# 82787.0
# 28.0
# 63.0
# 352.0
# 108.0
# 59.0
# 251.0
# 1806.0
# 194498.0
# 398.0
# 175.0
# 7634.0
# 40.0
# 28.0
# 395.0
# 37.0
# 215.0
# 45.0
# 47.0
# 28.0
# 252.0
# 72.0
# 75.0
# 32.0
# 136.0
# 31.0
# 359.0
# 135.0
# 72.0
# 356.0
# 372.0
# 346.0
# 366.0
# 51.0
# 47.0
# 163.0
# 31.0
# 52.0
# 36.0
# 153.0
# 28.0
# 73.0
# 64.0
# 377.0
# 74.0
# 51.0
# 8892.0
# 48.0
# 351.0
# 30.0
# 101.0
# 101365.0
# 36.0
# 40.0
# 354.0
# 54.0
# 130.0
# 65.0
# 81989.0
# 400.0
# 36.0
# 81.0
# 60.0
# 31.0
# 154.0
# 8757.0
# 163.0
# 15694.0
# 58.0
# 31.0
# 246.0
# 52.0
# 50.0
# 425.0
# 139.0
# 15483.0
# 36.0
# 70.0
# 392.0
# 32.0
# 28.0
# 108.0
# 32.0
# 200.0
# 254.0
# 151.0
# 354887.0
# 52.0
# 31.0
# 119.0
# 179.0
# 45.0
# 189.0
# 28.0
# 328.0
# 32.0
# 430.0
# 49.0
# 28.0
# 79.0
# 63.0
# 16406.0
# 386.0
# 44.0
# 56698.0
# 69.0
# 67.0
# 35.0
# 36.0
# 48.0
# 223.0
# 161.0
# 36.0
# 411.0
# 31.0
# 414.0
# 67.0
# 184.0
# 69.0
# 28.0
# 427.0
# 32.0
# 141.0
# 6519.0
# 82.0
# 129786.0
# 211.0
# 92.0
# 247.0
# 32.0
# 9484.0
# 77.0
# 158553.0
# 52.0
# 30.0
# 62.0
# 89.0
# 127.0
# 36.0
# 169340.0
# 30.0
# 46597.0
# 35.0
# 67.0
# 66.0
# 30.0
# 40.0
# 31.0
# 7984.0
# 9160.0
# 192.0
# 18842.0
# 56.0
# 62.0
# 31.0
# 51.0
# 62.0
# 299.0
# 89.0
# 59.0
# 54.0
# 156.0
# 28.0
# 126096.0
# 78196.0
# 136998.0
# 37.0
# 406.0
# 65.0
# 77.0
# 384.0
# 1670.0
# 32.0
# 69.0
# 29.0
# 346.0
# 66.0
# 42.0
# 33.0
# 68.0
# 29.0
# 424.0
# 73.0
# 82.0
# 35.0
# 33.0
# 156518.0
# 136652.0
# 70.0
# 305.0
# 178.0
# 148.0
# 50.0
# 144.0
# 36.0
# 30109.0
# 44.0
# 171426.0
# 63.0
# 224.0
# 28.0
# 54.0
# 87.0
# 23240.0
# 82.0
# 92421.0
# 42.0
# 39.0
# 44.0
# 89031.0
# 68.0
# 57.0
# 31.0
# 130307.0
# 220.0
# 34.0
# 86.0
# 405.0
# 328080.0
# 91.0
# 56.0
# 28763.0
# 41631.0
# 49.0
# 26335.0
# 86.0
# 146.0
# 58.0
# 54.0
# 29.0
# 30.0
# 49224.0
# 112.0
# 358.0
# 71.0
# 49.0
# 249.0
# 85.0
# 201.0
# 28.0
# 147.0
# 89.0
# 53.0
# 119.0
# 33.0
# 114.0
# 69.0
# 66.0
# 70.0
# 412.0
# 33.0
# 144.0
# 75843.0
# 38.0
# 52.0
# 41.0
# 65.0
# 53.0
# 67.0

# %% [markdown]
# ## 计算各个供应商的周数和

# %%
import xlrd
import numpy as np
import xlwt
file1="D:\\数学建模\\2021C\\a.xls"
data=xlrd.open_workbook(file1)
sheet=data.sheet_by_index(1)


ghl=np.zeros([sheet.nrows,sheet.ncols])
sghl=np.zeros([403,1])



for row in range(1,sheet.nrows):
    for col in range(2,sheet.ncols):
        ghl[row,col]=sheet.cell_value(row,col)
np.shape(ghl)
for row in range(403):
    sum=0
    for col in range(242):
        sum=sum+ghl[row,col]
    sghl[row,0]=sum

print(sghl)

file2=xlwt.Workbook()
sheet1= file2.add_sheet("sheet1",cell_overwrite_ok=True)
for i in range(1,403):
        sheet1.write(1,2,sghl[row-1,0])
for i in range(sheet.ncols):
        sheet1.write(0,i,sheet.cell_value(0,i))
for j in range(sheet.nrows):
    sheet1.write(j,0,sheet.cell_value(j,0))
for j in range(sheet.nrows):
    sheet1.write(j,1,sheet.cell_value(j,1))

file2.save("sa.xls")

# %%
import xlrd
sal=[]
sa={}

file1="D:\\数学建模\\2021C\\sa.xls"
data=xlrd.open_workbook(file1)
sheet=data.sheet_by_index(0)
nrows=sheet.nrows
ncols=sheet.ncols
for row in range(1,sheet.nrows):
    sa=dict([(sheet.cell_value(row,1),sheet.cell_value(row,2))])
    sal.append(sa)
for i in range(10):
    print(sal[i].values())
# Out:
# [328080.0]
# [136652.0]
# [130307.0]
# [92421.0]
# [41207.0]
# [31905.0]
# [30109.0]
# [28763.0]
# [26335.0]
# [23240.0]

# %%
from ast import Pass
from site import USER_BASE
import xlrd

def weekxStroe(a,nrows,ncols,x):
    a1=[]
    b=[]
    c=[]
    for i in range(1,nrows):
        if a[i][1]=="A":
            a1.append(a[i])
            # b.sort()
        elif a[i][1]=="B":
            b.append(a[i])
        else:
            c.append(a[i])
    for i in range(len(a1)):
         for j in range(len(a1)-1):
            if a1[j][x+1]<a1[j+1][x+1]:
                a1[j],a1[j+1]=a1[j+1],a1[j]
    for i in range(len(b)):
         for j in range(len(b)-1):
            if b[j][x+1]<b[j+1][x+1]:
                b[j],b[j+1]=b[j+1],b[j]
    for i in range(len(c)):
         for j in range(len(c)-1):
            if c[j][x+1]<c[j+1][x+1]:
                c[j],c[j+1]=c[j+1],c[j]
        
    
    return a1,b,c

def useWho(a1,x):
    sum=0
    use=set()
    for i in range(len(a1)):
        if sum<=28200:
            if a1[i][x+1]>=6000:
                sum=sum+6000
                use.add(a1[i][0])
            else: 
                sum=sum+a1[i][x+1]
                use.add(a1[i][0])
                
        if sum>28200:
            use.add(a1[i][0])
            break

        
    return use






file1="D:\\数学建模\\2021C\\a.xls"
data=xlrd.open_workbook(file1)
sheet=data.sheet_by_index(1)
a=[]
minx=[]

nrows=sheet.nrows
ncols=sheet.ncols

for row in range(sheet.nrows):
    b=[]
    for col in range(sheet.ncols):
        b.append(sheet.cell_value(row,col))
    a.append(b)
for i in range(1,241):
    a1,b,c=weekxStroe(a,nrows,ncols,i)
    
    usea=useWho(a1,i),
    useb=useWho(b,i)
    usec=useWho(c,i)
    x=min(len(usea),min(len(useb),len(usec)))
    if len(usec)==x:
        minx.append("usec")
    elif len(usea)==x:
        minx.append("usea")
    else:
        minx.append("useb")

    

# a1,b,c=weekxStroe(a,nrows,ncols,2)
# print(a1)
# print(minx)
print(useb)
# Out:
# {'S137', 'S389', 'S259', 'S168', 'S360', 'S308', 'S092', 'S010', 'S378', 'S105', 'S328', 'S230', 'S058', 'S018', 'S134', 'S330', 'S261', 'S045', 'S047', 'S057', 'S376', 'S248', 'S175', 'S166', 'S249', 'S340', 'S344', 'S390', 'S125', 'S111', 'S031', 'S311', 'S180', 'S346', 'S235', 'S322', 'S400', 'S191', 'S358', 'S399', 'S316', 'S112', 'S240', 'S048', 'S315', 'S095', 'S385', 'S335', 'S199', 'S225', 'S147', 'S387', 'S081', 'S224', 'S141', 'S179', 'S040', 'S401', 'S276', 'S215', 'S088', 'S287', 'S028', 'S233', 'S174', 'S019', 'S392', 'S222', 'S260', 'S232', 'S050', 'S140', 'S238', 'S272', 'S120', 'S402', 'S321', 'S176', 'S303', 'S216', 'S001', 'S139', 'S280', 'S009', 'S131', 'S367', 'S393', 'S397', 'S124', 'S386', 'S190', 'S310', 'S077', 'S319', 'S200', 'S353', 'S098', 'S193', 'S264', 'S327', 'S202', 'S371', 'S142', 'S298', 'S004', 'S197', 'S117', 'S073', 'S118', 'S188', 'S333', 'S079', 'S172', 'S069', 'S286', 'S338', 'S108', 'S029', 'S055', 'S169', 'S388', 'S036', 'S146', 'S364', 'S138', 'S324', 'S024', 'S366', 'S214', 'S375', 'S054', 'S256', 'S153', 'S258'}
